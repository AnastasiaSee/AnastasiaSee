# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaSee/AnastasiaSee/blob/main/idealista_scraper_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

url = "https://api.github.com/repos/AnastasiaSee/idealista-scraper/contents/data"
files = requests.get(url).json()

latest = sorted(files, key=lambda x: x['name'])[-1]['download_url']

df = pd.read_csv(latest)
df.head()
# Out:
#    propertyCode                                          thumbnail  \
# 0     109061730  https://img4.idealista.com/blur/480_360_mq/0/i...
# 1     110420914  https://img4.idealista.com/blur/480_360_mq/0/i...
# 2     110485053  https://img4.idealista.com/blur/480_360_mq/0/i...
# 3     110558235  https://img4.idealista.com/blur/480_360_mq/0/i...
# 4     109848839  https://img4.idealista.com/blur/480_360_mq/0/i...
#
#   externalReference  numPhotos floor     price propertyType operation   size  \
# 0             12466         67     3  798000.0         flat      sale  178.0
# 1        PV_ED_1081         29    bj  595000.0         flat      sale  173.0
# 2      PV_OD_1659_1         23     4  598000.0         flat      sale  107.0
# 3            234651         24     1  230000.0         flat      sale  107.0
# 4            298454         26     2  369000.0         flat      sale  138.0
#
#   exterior  ...  detailedType.typology           suggestedTexts.subtitle  \
# ...
